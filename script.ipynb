-- %% [markdown]
-- # [dbo].[config]

-- %%
USE [VPLAnalyzer]
GO

-- %%
/****** Object:  Table [dbo].[config]    Script Date: 9/16/2025 3:48:21 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[config](
	[key_name] [nvarchar](50) NOT NULL,
	[key_value] [nvarchar](200) NULL,
	[updated_at] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[key_name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[masterdata_issues]

-- %%
/****** Object:  Table [dbo].[masterdata_issues]    Script Date: 9/16/2025 3:48:21 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[masterdata_issues](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[date] [date] NOT NULL,
	[part_name] [nvarchar](50) NOT NULL,
	[inner_ref] [nvarchar](50) NULL,
	[issue_type] [nvarchar](20) NOT NULL,
	[expected] [nvarchar](100) NULL,
	[actual] [nvarchar](100) NULL,
	[details] [nvarchar](200) NULL,
	[created_at] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[required_parts]

-- %%
/****** Object:  Table [dbo].[required_parts]    Script Date: 9/16/2025 3:48:21 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[required_parts](
	[project_name] [nvarchar](20) NOT NULL,
	[required_part] [nvarchar](50) NOT NULL,
	[created_at] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[project_name] ASC,
	[required_part] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[sessions]

-- %%
/****** Object:  Table [dbo].[sessions]    Script Date: 9/16/2025 3:48:21 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[sessions](
	[token] [nvarchar](64) NOT NULL,
	[username] [nvarchar](50) NOT NULL,
	[created_at] [datetime] NULL,
	[expires_at] [datetime] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[token] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[users]

-- %%
/****** Object:  Table [dbo].[users]    Script Date: 9/16/2025 3:48:21 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[users](
	[username] [nvarchar](50) NOT NULL,
	[password_hash] [nvarchar](100) NOT NULL,
	[created_at] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[username] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[vpl_issues]

-- %%
/****** Object:  Table [dbo].[vpl_issues]    Script Date: 9/16/2025 3:48:21 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[vpl_issues](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[date] [date] NOT NULL,
	[vin] [nvarchar](20) NOT NULL,
	[project] [nvarchar](20) NOT NULL,
	[issue_type] [nvarchar](20) NOT NULL,
	[old_part] [nvarchar](50) NULL,
	[new_part] [nvarchar](50) NULL,
	[missing_part] [nvarchar](50) NULL,
	[details] [nvarchar](200) NULL,
	[created_at] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__config__updated___5812160E]

-- %%
ALTER TABLE [dbo].[config] ADD  DEFAULT (getdate()) FOR [updated_at]
GO

-- %% [markdown]
-- # [DF__masterdat__creat__52593CB8]

-- %%
ALTER TABLE [dbo].[masterdata_issues] ADD  DEFAULT (getdate()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__required___creat__5535A963]

-- %%
ALTER TABLE [dbo].[required_parts] ADD  DEFAULT (getdate()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__sessions__create__4CA06362]

-- %%
ALTER TABLE [dbo].[sessions] ADD  DEFAULT (getdate()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__users__created_a__49C3F6B7]

-- %%
ALTER TABLE [dbo].[users] ADD  DEFAULT (getdate()) FOR [created_at]
GO

-- %% [markdown]
-- # [DF__vpl_issue__creat__4F7CD00D]

-- %%
ALTER TABLE [dbo].[vpl_issues] ADD  DEFAULT (getdate()) FOR [created_at]
GO
